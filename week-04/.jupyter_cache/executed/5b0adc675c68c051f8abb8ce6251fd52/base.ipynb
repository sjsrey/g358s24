# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 7
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'/Users/serge/para/1_projects/course_385/24s/github/week-04':
  os.chdir(r'/Users/serge/para/1_projects/course_385/24s/github/week-04')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# /var/folders/r_/wrvvnby97qz9_wm2pzw40qhh0000gn/T/ipykernel_13679/1056851285.py:20: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats(fig_format)
# {"/Users/serge/mambaforge/envs/385f23/lib/python3.10/importlib/_bootstrap.py": 1687560340.4663458, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/importlib/_bootstrap_external.py": 1687560340.4713864, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/codecs.py": 1687560337.7702909, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/encodings/aliases.py": 1687560339.1612759, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/encodings/__init__.py": 1687560339.155254, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/encodings/utf_8.py": 1687560339.8500874, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/abc.py": 1687560337.6272814, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/io.py": 1687560337.9073498, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/stat.py": 1687560338.0990865, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/_collections_abc.py": 1687560337.5845973, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/genericpath.py": 1687560337.8622847, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/posixpath.py": 1687560337.9945896, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/os.py": 1687560337.9635649, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/_sitebuiltins.py": 1687560337.6142843, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/site-packages/_distutils_hack/__init__.py": 1694539296.0, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/site.py": 1687560338.065903, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/warnings.py": 1687560338.190189, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/importlib/__init__.py": 1687560340.4536576, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/importlib/machinery.py": 1687560340.4837003, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/importlib/_abc.py": 1687560340.457397, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/keyword.py": 1687560337.9137506, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/operator.py": 1687560337.9574203, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/reprlib.py": 1687560338.032587, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/collections/__init__.py": 1687560338.3531106, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/types.py": 1687560338.1780124, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/functools.py": 1687560337.858979, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/contextlib.py": 1687560337.8005772, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/importlib/util.py": 1687560340.4932184, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/runpy.py": 1687560338.0399394, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/enum.py": 1687560337.8402784, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/sre_constants.py": 1687560338.0892937, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/sre_parse.py": 1687560338.092586, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/sre_compile.py": 1687560338.0860662, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/copyreg.py": 1687560337.8110867, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/re.py": 1687560338.0292778, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/collections/abc.py": 1687560338.356638, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/typing.py": 1687560338.1810803, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/site-packages/ipykernel/_version.py": 1693880663.354675, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/lib-dynload/_json.cpython-310-darwin.so": 1687560385.362158, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/json/scanner.py": 1687560340.5403228, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/json/decoder.py": 1687560340.5332055, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/json/encoder.py": 1687560340.5370958, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/json/__init__.py": 1687560340.529989, "/Users/serge/mambaforge/envs/385f23/lib/python3.10/signal.py": 1687560338.06257, "/Users/serge/mambaforge/envs/385f23/lib/pyth ...

# %%
import numpy

def euclidean(pnt1, pnt2):
    dx = pnt1[0] - pnt2[0]
    dy = pnt1[1] - pnt2[1]
    return (dx**2 + dy**2) ** (1 / 2)


def manhattan(pnt1, pnt2):
    dx = pnt1[0] - pnt2[0]
    dy = pnt1[1] - pnt2[1]
    adx = numpy.abs(dx)
    ady = numpy.abs(dy)
    return adx + ady


def distance_composite(pnt1, pnt2, metric="euclidean"):
    if metric == "euclidean":
        return euclidean(pnt1, pnt2)
    else:
        return manhattan(pnt1, pnt2)
